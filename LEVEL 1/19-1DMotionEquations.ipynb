# %%
def motionCalculation(intial_velocity=None, final_velocity=None, distance_covered=None, acceleration=None, time_needed=None):
    if (intial_velocity):
        u = intial_velocity
    if (final_velocity):
        v = final_velocity
    if (distance_covered):
        s = distance_covered
    if (acceleration):
        if acceleration == "g":
            a = 9.80665
        else:
            a = acceleration
    if (time_needed):
        t = time_needed
    
    if ()
