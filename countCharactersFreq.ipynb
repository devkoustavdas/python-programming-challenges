# %% [markdown]
# **Count Character Frequency**
# - Write a function that takes a string and returns a dictionary with the frequency of each character.

# %%
def countCharactersFreq(text):
    charFreq = {}
    for char in text:
        if char.isalpha():
            if char not in charFreq:
                charFreq[char] = 0
            charFreq[char] += 1
    for key, value in charFreq.items():
        print(f"{key} appeared {value} times")

# %%
countCharactersFreq("My friends would describe me as a approachable, helpful and motivated person. I have quite a bonding with many of my classmates.")
# Out:
# M appeared 1 times
# y appeared 3 times
# f appeared 3 times
# r appeared 4 times
# i appeared 6 times
# e appeared 11 times
# n appeared 6 times
# d appeared 6 times
# s appeared 7 times
# w appeared 2 times
# o appeared 6 times
# u appeared 3 times
# l appeared 5 times
# c appeared 3 times
# b appeared 3 times
# m appeared 5 times
# a appeared 12 times
# p appeared 4 times
# h appeared 4 times
# t appeared 5 times
# v appeared 2 times
# I appeared 1 times
# q appeared 1 times
# g appeared 1 times
