# %% [markdown]
# **Bank Account**
# - Create a class BankAccount with attributes balance and owner an.
# - Include methods deposit (amount) and withdraw (amount).
# - Ensure withdraw prevents overdrafts.

# %%
class BankAccount():
    accountType = "Salary"
    
    def __init__(self, balance, owner):
        self._balance = balance
        self.owner = owner

    @property
    def checkBalance(self):
        print(f"Owner: {self.owner}\nBalance: ₹{self._balance}")
        
    def deposit(self, depositAmount):
        self._balance += depositAmount
        print(f"₹{depositAmount} has been added to the account.\nCurrent Balance: {self._balance}")
        
    def withdraw(self, withdrawAmount):
        if(withdrawAmount <= self._balance):
            self._balance -= withdrawAmount
            print(f"₹{withdrawAmount} has been deducted to the account.\nCurrent Balance: {self._balance}")
        else:
            print(f"Insufficient funds. Cannot withdraw ₹{withdrawAmount}.\nYour current balance is ₹{self._balance}.")

# %%
john = BankAccount(15600, "John Doe")

# %%
john.accountType
# Out:
# 'Salary'

# %%
john.checkBalance
# Out:
# Owner: John Doe
# Balance: ₹15600

# %%
john.deposit(5000)
# Out:
# ₹5000 has been added to the account.
# Current Balance: 20600

# %%
john.withdraw(21000)
# Out:
# Insufficient funds. Cannot withdraw ₹21000.
# Your current balance is ₹20600.

# %%
john.withdraw(2000)
# Out:
# ₹2000 has been deducted to the account.
# Current Balance: 18600
